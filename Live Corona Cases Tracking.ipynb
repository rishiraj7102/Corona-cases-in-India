# %%
import pandas as pd
from pywebio.input import *
from pywebio.output import *


def positivecases(df,state):
    cases=df[df.state_name==state]['positive'].values[0]
    return cases
def activecases(df,state):
    cases=df[df.state_name==state]['active'].values[0]
    return cases
def curedcases(df,state):
    cases = df[df.state_name == state]['cured'].values[0]
    return cases
def death(df,state):
    cases = df[df.state_name == state]['death'].values[0]
    return cases
def newactive(df,state):
    cases = df[df.state_name == state]['new_active'].values[0]
    return cases
def newpositive(df,state):
    cases = df[df.state_name == state]['new_positive'].values[0]
    return cases
def newcured(df,state):
    cases = df[df.state_name == state]['new_cured'].values[0]
    return cases
def newdeath(df,state):
    cases = df[df.state_name == state]['new_death'].values[0]
    return cases



if __name__=='__main__':
    df=pd.read_json('https://www.mohfw.gov.in/data/datanew.json')
    states=list(df.state_name.values)
    state=select('Select the state',states)
    l=['Positive','Active','Cured','Deaths','New Positive','New Active','New Cured','New Deaths']
    feature=select('Which cases you want to see',['Positive','Active','Cured','Deaths','New Positive','New Active','New Cured','New Deaths'])
    if feature=='Positive':
        x=positivecases(df,state)
        put_text(f'The {feature} cases are {x}')
    elif feature=='Active':
        x=activecases(df,state)
        put_text(f'The {feature} cases are {x}')
    elif feature=='Cured':
        x=curedcases(df,state)
        put_text(f'The {feature} cases are {x}')
    elif feature=='Deaths':
        x=death(df,state)
        put_text(f'The {feature} cases are {x}')
    elif feature=='New Positive':
        x=newpositive(df,state)
        put_text(f'The {feature} cases are {x}')
    elif feature=='New Active':
        x=newactive(df,state)
        put_text(f'The {feature} cases are {x}')
    elif feature=='New Cured':
        x=newcured(dfd,state)
        put_text(f'The {feature} cases are {x}')
    elif feature=='New Deaths':
        x=newdeath(df,state)
        put_texte(f'The {feature} cases are {x}')
